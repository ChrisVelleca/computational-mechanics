# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
plt.style.use('fivethirtyeight')

from numpy.random import default_rng

# %% [markdown]
# # HW_02
#
# ## Calculating and reporting $\pi$
#
# Calculate your own value of $\pi$ using the random x- and y-coordinates. You need to report your findings to other engineers in your field. You should explain _why_ and _how_ you are calculating $\pi$, then describe the data with at least one plot. You can use more if it helps to explain the process or a point you are trying to make, here are some examples from our first $\pi$ calculation.

# %%
rng = default_rng(42)
plt.figure()

ax1 = plt.subplot(2, 2, (1, 2))
for N in range(100,1001, 100):
    trials = 100
    pi_trial = np.zeros(trials)
    for i in range(trials):
        x = rng.random(N)
        y = rng.random(N)

        r = x**2 + y**2

        pi_trial[i] = np.sum(r < 1**2)/N*4

    mean_pi = np.mean(pi_trial)
    std_pi = np.std(pi_trial)

    ax1.plot(N*np.ones(trials), pi_trial, 'ko', alpha = 0.1)
plt.title(r'Value of $\pi=${:1.3f}$\pm${:1.3f}'.format(mean_pi, std_pi));
ax2 = plt.subplot(2, 2, 3)
ax2.hist(pi_trial, 20, density=True)


x = np.linspace(3, 3.3)
pi_pdf = stats.norm.pdf(x, loc = mean_pi, scale = std_pi)
ax2.plot(x, pi_pdf)

ax3 = plt.subplot(2, 2, 4)
ax3.boxplot(pi_trial, vert=False);

# %%
ax1 = plt.subplot(1, 1, 1)
for N in range(100,1001, 100):
    trials = 100
    pi_trial = np.zeros(trials)
    for i in range(trials):
        x = rng.random(N)
        y = rng.random(N)

        r = x**2 + y**2

        pi_trial[i] = np.sum(r < 1**2)/N*4

    mean_pi = np.mean(pi_trial)
    std_pi = np.std(pi_trial)
    plt.plot(N*np.ones(trials), pi_trial, 'ko', alpha = 0.1)

# %%
rng = default_rng(42)
plt.figure()

ax1 = plt.subplot(2, 2, (1, 2))
for N in range(100,1001, 100):
    trials = 10000
    pi_trial = np.zeros(trials)
    for i in range(trials):
        x = rng.random(N)
        y = rng.random(N)

        r = x**2 + y**2

        pi_trial[i] = np.sum(r < 1**2)/N*4

    mean_pi = np.mean(pi_trial)
    std_pi = np.std(pi_trial)

    ax1.plot(N*np.ones(trials), pi_trial, 'ko', alpha = 0.1)
plt.title(r'Value of $\pi=${:1.3f}$\pm${:1.3f}'.format(mean_pi, std_pi));
ax2 = plt.subplot(2, 2, 3)
ax2.hist(pi_trial, 20, density=True)


x = np.linspace(3, 3.3)
pi_pdf = stats.norm.pdf(x, loc = mean_pi, scale = std_pi)
ax2.plot(x, pi_pdf)

ax3 = plt.subplot(2, 2, 4)
ax3.boxplot(pi_trial, vert=False);

# %%
ax1 = plt.subplot(1, 1, 1)
for N in range(100,1001, 100):
    trials = 10000
    pi_trial = np.zeros(trials)
    for i in range(trials):
        x = rng.random(N)
        y = rng.random(N)

        r = x**2 + y**2

        pi_trial[i] = np.sum(r < 1**2)/N*4

    mean_pi = np.mean(pi_trial)
    std_pi = np.std(pi_trial)
    plt.plot(N*np.ones(trials), pi_trial, 'ko', alpha = 0.1)

# %%
rng = default_rng(42)
plt.figure()

ax1 = plt.subplot(2, 2, (1, 2))
for N in range(100,10001, 100):
    trials = 100000
    pi_trial = np.zeros(trials)
    for i in range(trials):
        x = rng.random(N)
        y = rng.random(N)

        r = x**2 + y**2

        pi_trial[i] = np.sum(r < 1**2)/N*4

    mean_pi = np.mean(pi_trial)
    std_pi = np.std(pi_trial)

    ax1.plot(N*np.ones(trials), pi_trial, 'ko', alpha = 0.1)
plt.title(r'Value of $\pi=${:1.3f}$\pm${:1.3f}'.format(mean_pi, std_pi));
ax2 = plt.subplot(2, 2, 3)
ax2.hist(pi_trial, 20, density=True)


x = np.linspace(3, 3.3)
pi_pdf = stats.norm.pdf(x, loc = mean_pi, scale = std_pi)
ax2.plot(x, pi_pdf)

ax3 = plt.subplot(2, 2, 4)
ax3.boxplot(pi_trial, vert=False);

# %% [markdown]
# ## Some points to consider in your report
#
# - $\pi$ is not a random variable, but the probability that you land in a circle vs a square if your coordinates are x = 0-r and y = 0-r is $\frac{A_{circle}}{A_{square}} = \frac{\pi r^2}{4r^2} = \frac{\pi}{4}$.
# - When is the mean "close enough" to $\pi$?
# - What do the tails of the calculated $\pi$ values tell us about the prediction?
# - What else do you notice in your analysis?

# %% [markdown]
# In this assignment we look to utilize the Monte Carlo method to determine the value of pi. To do so we utilize a 1x1 square with a quarter circle in it with a radius of 1. The probability of uniformly distributed points falling within the quarter circle should yeild a result close to pi/4. This probalilyt is given by the equation $\frac{A_{circle}}{A_{square}} = \frac{\pi r^2}{4r^2} = \frac{\pi}{4}$. Multiplying the probability by 4 we can get a value close to pi.
# In order to get the pi value as precise as possible varibles that could be altered are the N for the sample size and the number of trails ran. Running this simulation will provide the standard deviation of the results that we can analyze to determien the precision of this method. This program outputs a scatterplot, histogram and x plot. The scatterplot shows the pi value estimates vs the sample size. As N increases the spread of the stimates reduces indicating a convergance oward the true value of pi.
# The histogram shows the distrobution of pi values obtained across all trails for N. The shape of this distrobution becomes more concentrated around the true value as N increases.
# The box plot highlights the interquartile range and potential outliser shwoing the variability in the estimation process.
# Many trials where attempted increasing the number of trails and N value simotaneously.
# When attempting 1,000,000 trails the program buffered for a long time and was unable to output a result. While 100,000 was able to ouput a result it still took some time to run. The 100,000 trial run output a very clean histogram
